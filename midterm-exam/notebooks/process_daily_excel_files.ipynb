# %%
import json
import pickle

import pandas as pd
import numpy as np

# %%
airports_df = pd.read_csv('../utility_dataframes/airports_df.csv', index_col=0)

# %%
column_names = [
    'FirstName',
    'LastName',
    'Gender',
    'FlightNumber',
    'Date',
    'Time',
    'DepartureCountry',
    'DepartureCity',
    'DepartureAirport',
    'ArrivalCountry',
    'ArrivalCity',
    'ArrivalAirport',
    'AirlineName',
    'LoyaltyStatus'
]

# %%
with open('../utility_dataframes/dates.pkl', 'rb') as file:
    dates = pickle.load(file)

# %%
airline_names = {
    'SU': 'aeroflot',
    'OK': 'chech airlines',
    'KE': 'korean air',
    'UX': 'air europa',
    'CZ': 'china southern airlines',
    'AF': 'air france',
    'KL': 'klm',
    'VN': 'vietnam airlines',
    'RO': 'tarom',
    'AZ': 'alitalia',
    'CI': 'china airlines',
    'MF': 'xiamen air',
    'ME': 'middle east airlines',
    'MU': 'china eastern airlines',
    'AR': 'argentinas',
    'GA': 'garudas indonesia',
    'DL': 'delta airlines',
    'KQ': 'kenya airways',
    'SV': 'saudi arabian airlines',
    'AM': 'aeromexico'
}

def convert_airline_name(name, airline_names=airline_names):
    return airline_names.get(name[:2], np.nan)

# %%
def process_sheet(df):
    if df.iloc[1, 5] is not np.nan:
        return False
    flight_info = {}
    flight_info['FirstName'] = (df.iloc[1, 1]).lower()
    flight_info['Gender'] = 'M' if df.iloc[1, 0] == 'MR' else 'F'
    flight_info['FlightNumber'] = df.iloc[3, 0]
    flight_info['Date'] = df.iloc[7, 0]
    flight_info['Time'] = df.iloc[7, 2]
    flight_info['DepartureCity'] = (df.iloc[3, 3]).lower()
    flight_info['DepartureAirport'] = df.iloc[5, 3]
    flight_info['ArrivalCity'] = (df.iloc[3, 7]).lower()
    flight_info['ArrivalAirport'] = df.iloc[5, 7]
    return flight_info

# %%
def process_file(df):
    result_df = pd.DataFrame(columns=column_names)
    no_match_airport = set()
    for sheet in df.values():
        flight_info = process_sheet(sheet)
        if not flight_info:
            continue
        try: 
            flight_info['DepartureCountry'] = (airports_df.loc[airports_df['code'] == flight_info['DepartureAirport'], 'country'].iloc[0]).lower()
        except IndexError:
            no_match_airport.add(flight_info['DepartureAirport'])

        try: 
            flight_info['ArrivalCountry'] = (airports_df.loc[airports_df['code'] == flight_info['ArrivalAirport'], 'country'].iloc[0]).lower()
        except IndexError:
            no_match_airport.add(flight_info['ArrivalAirport'])


        result_df = result_df.append(flight_info, ignore_index=True)
        result_df['AirlineName'] = result_df['FlightNumber'].apply(convert_airline_name)

    print('No match for airports: ', no_match_airport)
    return result_df

# %%
airline_names = set()

# %%
path_to_excel_files = './YourBoardingPassDotAero/YourBoardingPassDotAero-'

for date in dates[200:]:
    df = pd.read_excel(path_to_excel_files + date + '.xlsx', sheet_name=None,
                  names=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])

    result_df = process_file(df)
    result_df.to_csv(f'./result_dfs/result_df_{date}.csv')
    print(f'{date} proccesseed')
# Out:
# No match for airports:  {'DQA', 'GYS', 'JUH', 'LDS', 'LOP', 'RIZ', 'ZUJ', 'NLH', 'JXS', 'HNY', 'ZYI', 'BAR', 'KVN', 'JIQ', 'HXD', 'NGQ', 'JNG', 'DSS', 'FLZ'}
# 2017-07-20 proccesseed
# No match for airports:  {'ZUJ', 'DYN', 'LOP', 'DTB', 'AEB', 'JXS', 'HNY', 'ZYI', 'TCZ', 'ECP', 'UKA', 'JNG', 'WNH', 'HDG', 'LPF', 'DSS'}
# 2017-07-21 proccesseed
# No match for airports:  {'WLI', 'GYS', 'HMI', 'DQA', 'BUW', 'RIZ', 'WUT', 'WDS', 'HNY', 'JSJ', 'TCZ', 'ECP', 'RAQ', 'LFQ', 'NYT', 'LLV', 'DSS', 'HDG', 'BWX'}
# 2017-07-22 proccesseed
# No match for airports:  {'DQA', 'WLI', 'DYN', 'KTG', 'CWJ', 'ZYI', 'SQD', 'BAR', 'FSZ', 'LFQ', 'JNG', 'QSZ'}
# 2017-07-23 proccesseed
# No match for airports:  {'KVN', 'HPG', 'DQA'}
# 2017-07-24 proccesseed
# No match for airports:  {'DQA', 'KOS', 'DYN', 'RIZ', 'JXS', 'HNY', 'WDS', 'BAR', 'TCZ', 'ZYI', 'KVN', 'JBB', 'ECP', 'WNH', 'HDG'}
# 2017-07-25 proccesseed
# No match for airports:  {'DQA', 'GYS', 'DYN', 'LOP', 'ZYI', 'ECP', 'JIQ', 'UKA', 'LFQ', 'FSZ', 'QSZ', 'DSS'}
# 2017-07-26 proccesseed
# No match for airports:  {'KTG', 'SHS', 'KVN', 'DSS', 'DQA', 'WLI', 'TCZ', 'ECP', 'HDG', 'DYN', 'RIZ', 'JXS', 'BAR', 'WNH', 'KOS', 'ZUJ', 'LOP', 'WDS', 'CWJ', 'SQD', 'FSZ', 'PKN', 'LPF'}
# 2017-07-27 proccesseed
# No match for airports:  {'DYN', 'LOP', 'SHF', 'KTG', 'WDS', 'JXS', 'CWJ', 'HTT', 'TCZ', 'GNS', 'KVN', 'ECP', 'YKH', 'JXA', 'NYT', 'LLV', 'BWX'}
# 2017-07-28 proccesseed
# No match for airports:  {'WLI', 'GYS', 'LDS', 'DYN', 'KTG', 'WUT', 'WDS', 'BWX', 'ZYI', 'TCZ', 'BEJ', 'CHG', 'JUH', 'LPF', 'DSS'}
# 2017-07-29 proccesseed
# No match for airports:  {'DYN', 'CWJ', 'PKN', 'DSS', 'BWX'}
# 2017-07-30 proccesseed
# No match for airports:  {'DQA', 'BUW', 'LDS', 'LOP', 'DCY', 'RIZ', 'JXS', 'HNY', 'ZYI', 'BEJ', 'TCZ', 'YSQ', 'TVX', 'LFQ', 'DTB'}
# 2017-07-31 proccesseed
# No match for airports:  {'DQA', 'GYS', 'DYN', 'LOP', 'LDS', 'NLH', 'WDS', 'HNY', 'CWJ', 'BAR', 'BEJ', 'SQD', 'KVN', 'TCZ', 'JIC', 'LPF', 'BWX'}
# 2017-08-01 proccesseed
# No match for airports:  {'WLI', 'HNY', 'TCZ'}
# 2017-08-02 proccesseed
# No match for airports:  {'LDS', 'LOP', 'DCY', 'PRA', 'AEB', 'WDS', 'HNY', 'ZYI', 'KVN', 'ECP', 'FSZ', 'HXD', 'JMJ', 'RAQ', 'DSS'}
# 2017-08-03 proccesseed
# No match for airports:  {'DQA', 'WMT', 'LDS', 'LOP', 'PKN', 'DYN', 'JXS', 'WDS', 'NDS', 'HTT', 'BAR', 'TCZ', 'KVN', 'SHS', 'ECP', 'FSZ', 'BEJ', 'JIC', 'GYU', 'LLV'}
# 2017-08-04 proccesseed
# No match for airports:  {'BUW', 'SHF', 'HNY', 'ZYI', 'BAR', 'SQD', 'BEJ', 'TCZ', 'KVN', 'FSZ', 'LFQ', 'JNG', 'JIC', 'GYU', 'NYT', 'HDG', 'DSS'}
# 2017-08-05 proccesseed
# No match for airports:  {'GYS', 'DYN', 'LOP', 'RIZ', 'GMQ', 'WDS', 'ZYI', 'BAR', 'KVN', 'ECP', 'JNG', 'JMJ', 'WNH', 'HDG', 'DSS'}
# 2017-08-06 proccesseed
# No match for airports:  {'WMT', 'KTG', 'KVN', 'TVX', 'DSS', 'DQA', 'HMI', 'WLI', 'LDS', 'TCZ', 'ECP', 'YKH', 'JXA', 'HDG', 'HNY', 'BAR', 'JIQ', 'GYU', 'LOP', 'WDS', 'JNG', 'PKN', 'DTB'}
# 2017-08-07 proccesseed
# No match for airports:  {'WMT', 'BEJ', 'KVN', 'LLV', 'DSS', 'HMI', 'GMQ', 'AEB', 'TCZ', 'ECP', 'LFQ', 'JIC', 'CHG', 'QSZ', 'DYN', 'RIZ', 'JIQ', 'BWX', 'GYS', 'WDS', 'FSZ', 'JNG', 'JMJ', 'NYT'}
# 2017-08-08 proccesseed
# No match for airports:  {'DQA', 'GYS', 'KOS', 'ZUJ', 'SHF', 'LOP', 'DYN', 'HNY', 'ECP', 'JNG', 'HDG', 'DSS'}
# 2017-08-09 proccesseed
# No match for airports:  {'DYN', 'SQG', 'WDS', 'TCZ', 'SHS', 'GNS', 'FSZ', 'FYN'}
# 2017-08-10 proccesseed
# No match for airports:  {'DQA', 'WMT', 'WLI', 'DYN', 'LOP', 'RIZ', 'KTG', 'WUT', 'JXS', 'CWJ', 'BAR', 'FSZ', 'NYT', 'BWX', 'DSS'}
# 2017-08-11 proccesseed
# No match for airports:  {'KTG', 'HMI', 'DQA', 'PRA', 'TCZ', 'JBB', 'ECP', 'LFQ', 'QSZ', 'DYN', 'SXK', 'BAR', 'JIQ', 'GYS', 'LLB', 'ZUJ', 'LOP', 'WUT', 'FSZ', 'JNG', 'NYT'}
# 2017-08-12 proccesseed
# No match for airports:  {'WMT', 'KTG', 'KVN', 'DSS', 'WLI', 'DQA', 'LDS', 'RKZ', 'AEB', 'TCZ', 'ECP', 'CHG', 'HNY', 'BWX', 'BUW', 'ZUJ', 'LOP', 'WUT', 'CWJ', 'NYT', 'PKN'}
# 2017-08-13 proccesseed
# No match for airports:  {'DQA', 'LLB', 'LOP', 'WDS', 'LLV'}
# 2017-08-14 proccesseed
# No match for airports:  {'WLI', 'DQA', 'DYN', 'LOP', 'LDS', 'SQG', 'NLH', 'WDS', 'YSQ', 'BEJ', 'KVN', 'RAQ'}
# 2017-08-15 proccesseed
# No match for airports:  {'WLI', 'JXS', 'LOP', 'DTB'}
# 2017-08-16 proccesseed
# No match for airports:  {'WMT', 'KVN', 'DSS', 'HMI', 'RKZ', 'HPG', 'AEB', 'ECP', 'CHG', 'HDG', 'DYN', 'TVS', 'BAR', 'GNS', 'JIQ', 'BWX', 'LLB', 'KOS', 'LOP', 'PSU', 'JNG', 'NYT'}
# 2017-08-17 proccesseed
# No match for airports:  {'HMI', 'GYS', 'LUW', 'DQA', 'BUW', 'SHF', 'HPG', 'GMQ', 'HNY', 'CWJ', 'JSJ', 'YSQ', 'SQD', 'TVX', 'FSZ', 'UKA', 'JNG', 'HDG', 'DSS'}
# 2017-08-18 proccesseed
# No match for airports:  {'BUW', 'GYS', 'WMT', 'LOP', 'YTY', 'WUT', 'NDS', 'BAR', 'TCZ', 'KVN', 'FSZ', 'YKH', 'LFQ', 'JNG', 'GYU', 'NYT', 'DSS'}
# 2017-08-19 proccesseed
# No match for airports:  {'WLI', 'DQA', 'HMI', 'LDS', 'LOP', 'TVS', 'KTG', 'DYN', 'GMQ', 'JXS', 'WDS', 'HNY', 'TCZ', 'KVN', 'TVX', 'UKA', 'DSS'}
# 2017-08-20 proccesseed
# No match for airports:  {'DQA', 'WMT', 'LOP', 'SHF', 'QSZ'}
# 2017-08-21 proccesseed
# No match for airports:  {'HMI', 'ZUJ', 'LDS', 'LOP', 'NLH', 'PSU', 'LLV', 'WDS', 'HNY', 'JXS', 'KVN', 'RAQ', 'TVX', 'ECP', 'LFQ', 'JNG', 'JXA', 'NYT', 'PKN'}
# 2017-08-22 proccesseed
# No match for airports:  {'DQA', 'DYN', 'LOP', 'WDS', 'NDS', 'HNY', 'BAR', 'TCZ', 'LSW', 'GNS', 'FSZ', 'JNG', 'LLV'}
# 2017-08-23 proccesseed
# No match for airports:  {'HMI', 'KVN', 'PRA'}
# 2017-08-24 proccesseed
# No match for airports:  {'WMT', 'DCY', 'KTG', 'BEJ', 'KVN', 'TVX', 'DSS', 'DQA', 'WLI', 'LDS', 'HPG', 'PRA', 'TCZ', 'ECP', 'LFQ', 'HNY', 'ZYI', 'BAR', 'GNS', 'RAQ', 'BUW', 'WDS', 'CWJ', 'FSZ', 'JNG', 'PKN'}
# 2017-08-25 proccesseed
# No match for airports:  {'HNY', 'ZYI', 'BAR', 'SQD', 'FYN', 'RAQ', 'HDG', 'BWX'}
# 2017-08-26 proccesseed
# No match for airports:  {'KTG', 'JSJ', 'KVN', 'LLV', 'DSS', 'HMI', 'LDS', 'TCZ', 'ECP', 'LFQ', 'JXA', 'HDG', 'HNY', 'ZYI', 'BAR', 'GYS', 'ZUJ', 'LOP', 'SHF', 'WUT', 'CWJ', 'HTT', 'FSZ', 'UKA', 'JNG', 'LPF'}
# 2017-08-27 proccesseed
# No match for airports:  {'WLI', 'LUW', 'KOS', 'DYN', 'LOP', 'LDS', 'DQA', 'LLO', 'RIZ', 'JXS', 'HNY', 'WDS', 'KVN', 'JIQ', 'ECP', 'DSS'}
# 2017-08-28 proccesseed
# No match for airports:  {'LUW', 'DYN', 'LOP', 'HPG', 'JXS', 'HTT', 'TCZ', 'YSQ', 'KVN', 'JBB', 'LFQ', 'JNG', 'WNH', 'LLV', 'LPF', 'DSS'}
# 2017-08-29 proccesseed
# No match for airports:  {'DQA', 'KOS', 'LDS', 'ZUJ', 'LLO', 'JXS', 'ZYI', 'HTT', 'TCZ', 'BAR', 'GNS', 'KVN', 'ECP', 'JIQ', 'JNG', 'JXA', 'NYT', 'LLV', 'DSS'}
# 2017-08-30 proccesseed
# No match for airports:  {'DQA', 'NGQ', 'DYN', 'LOP', 'RIZ', 'YTY', 'TVS', 'DCY', 'WDS', 'ZYI', 'JIC', 'TCZ', 'JMJ', 'LSW', 'TVX', 'JXA', 'NYT', 'RAQ', 'HDG', 'LPF'}
# 2017-08-31 proccesseed
# No match for airports:  {'KTG', 'BEJ', 'HXD', 'LLV', 'WLI', 'DQA', 'LDS', 'RKZ', 'AEB', 'TCZ', 'CHG', 'JXA', 'HDG', 'DYN', 'JXS', 'HNY', 'ZYI', 'GYU', 'WNH', 'LOP', 'PSU', 'HTT', 'JNG'}
# 2017-09-01 proccesseed
# No match for airports:  {'ZUJ', 'KTG', 'WUT', 'WDS', 'BAR', 'TCZ', 'JIC', 'KVN', 'ECP', 'FSZ', 'YKH', 'JXA', 'LLV', 'DSS'}
# 2017-09-02 proccesseed
# No match for airports:  {'DQA', 'LDS', 'LOP', 'DYN', 'LLO', 'WUT', 'BAR', 'YSQ', 'ECP', 'JNG', 'FYN', 'LZY', 'DSS'}
# 2017-09-03 proccesseed
# No match for airports:  {'DQA', 'LOP', 'WDS', 'KVN', 'ECP', 'YKH', 'WNH', 'LLV'}
# 2017-09-04 proccesseed
# No match for airports:  {'DQA', 'WDS', 'SQD', 'SHS', 'UKA', 'JNG'}
# 2017-09-05 proccesseed
# No match for airports:  {'HMI', 'DQA', 'WLI', 'LOP', 'SHF', 'KTG', 'WUT', 'AEB', 'JXA', 'JXS', 'WDS', 'CWJ', 'YSQ', 'KVN', 'ECP', 'JMJ', 'RAQ', 'HDG'}
# 2017-09-06 proccesseed
# No match for airports:  {'RIZ', 'HNY', 'ZYI', 'TCZ', 'KVN', 'JNG', 'NYT', 'WNH', 'LPF'}
# 2017-09-07 proccesseed
# No match for airports:  {'DQA', 'DYN', 'NLH', 'LLO', 'WDS', 'BAR', 'KVN', 'ECP'}
# 2017-09-08 proccesseed
# No match for airports:  {'LUW', 'DQA', 'DYN', 'TVS', 'RIZ', 'ZYI', 'BAR', 'CWJ', 'TCZ', 'GNS', 'KVN', 'ECP', 'JSJ', 'JNG', 'JMJ', 'WNH', 'LPF', 'DSS'}
# 2017-09-09 proccesseed
# No match for airports:  {'KTG', 'JUH', 'DSS', 'DQA', 'WLI', 'RKZ', 'TCZ', 'ECP', 'QSZ', 'DYN', 'RIZ', 'LLO', 'HNY', 'ZYI', 'GNS', 'WNH', 'RAQ', 'GYS', 'ZUJ', 'LOP', 'HTT', 'SQD', 'JNG', 'NYT', 'LPF'}
# 2017-09-10 proccesseed
# No match for airports:  {'DCY', 'KTG', 'KVN', 'SHS', 'LLV', 'DSS', 'WLI', 'DQA', 'RKZ', 'GMQ', 'TCZ', 'ECP', 'JXA', 'DYN', 'ZYI', 'WNH', 'ZUJ', 'LOP', 'PSU', 'UKA', 'PKN', 'DTB'}
# 2017-09-11 proccesseed
# No match for airports:  {'WMT', 'DQA', 'LOP', 'KTG', 'JXS', 'HNY', 'ZYI', 'KVN', 'UKA', 'JNG', 'NYT'}
# 2017-09-12 proccesseed
# No match for airports:  {'ZUJ', 'LDS', 'DYN', 'DCY', 'LOP', 'ZYI', 'BEJ', 'KVN', 'LSW', 'FSZ', 'JNG', 'BWX'}
# 2017-09-13 proccesseed
# No match for airports:  {'KOS', 'DYN', 'LOP', 'PRA', 'GMQ', 'WDS', 'JXS', 'ZYI', 'BAR', 'TCZ', 'KVN'}
# 2017-09-14 proccesseed
# No match for airports:  {'DQA', 'BUW', 'DYN', 'LOP', 'PRA', 'GMQ', 'JXA', 'LSW', 'KVN', 'ECP', 'FLZ', 'GYU', 'DSS', 'BWX'}
# 2017-09-15 proccesseed
# No match for airports:  {'DQA', 'GYS', 'LDS', 'RKZ', 'LOP', 'MJU', 'WDS', 'ZYI', 'SXK', 'TCZ', 'SQD', 'GNS', 'ECP', 'UKA', 'LFQ', 'JNG', 'FYN', 'LPF', 'DSS'}
# 2017-09-16 proccesseed
# No match for airports:  {'LUW', 'WMT', 'DQA', 'HMI', 'WLI', 'RIZ', 'LDS', 'WUT', 'LOP', 'MJU', 'ZYI', 'BAR', 'TCZ', 'KVN', 'ECP', 'JNG', 'QSZ', 'WNH', 'HDG'}
# 2017-09-17 proccesseed
# No match for airports:  {'DQA', 'ZUJ', 'LDS', 'LOP', 'DCY', 'HPG', 'RIZ', 'WDS', 'HNY', 'ZYI', 'JIC', 'KVN', 'ECP', 'JNG', 'CHG'}
# 2017-09-18 proccesseed
# No match for airports:  {'PRA', 'WUT', 'ZYI', 'SHS', 'LFQ'}
# 2017-09-19 proccesseed
# No match for airports:  {'JNG', 'LPF'}
# 2017-09-20 proccesseed
# No match for airports:  {'BUW', 'WLI', 'YTY', 'GMQ', 'WDS', 'KVN', 'SHS', 'GNS', 'FSZ', 'JNG', 'GYU', 'DSS'}
# 2017-09-21 proccesseed
# No match for airports:  {'WMT', 'NLH', 'KVN', 'TVX', 'LLV', 'WLI', 'DQA', 'RKZ', 'TCZ', 'JBB', 'CHG', 'DYN', 'JXS', 'ZYI', 'SXK', 'BAR', 'KOS', 'ZUJ', 'LOP', 'WUT', 'SQD', 'JMJ', 'NYT'}
# 2017-09-22 proccesseed
# No match for airports:  {'WMT', 'NLH', 'JSJ', 'LLV', 'WLI', 'DQA', 'HMI', 'TCZ', 'YKH', 'QSZ', 'DYN', 'RIZ', 'JIQ', 'GYU', 'WNH', 'BUW', 'LOP', 'WDS', 'HTT', 'SQD', 'JNG', 'LPF'}
# 2017-09-23 proccesseed
# No match for airports:  {'DQA', 'WMT', 'ZUJ', 'LOP', 'RHD', 'HPG', 'WUT', 'HNY', 'ZYI', 'YSQ', 'GNS', 'KVN', 'FSZ', 'JNG', 'JXA'}
# 2017-09-24 proccesseed
# No match for airports:  {'DCY', 'KVN', 'HXD', 'DSS', 'HMI', 'DQA', 'TCZ', 'YKH', 'LFQ', 'DYN', 'JXS', 'HNY', 'ZYI', 'BAR', 'GNS', 'LSW', 'JIQ', 'WNH', 'BWX', 'ZUJ', 'LOP', 'WDS', 'CWJ'}
# 2017-09-25 proccesseed
# No match for airports:  {'DCY', 'BEJ', 'KVN', 'DSS', 'DQA', 'RKZ', 'HPG', 'PRA', 'AEB', 'GMQ', 'TCZ', 'JBB', 'ECP', 'JXA', 'RHD', 'DYN', 'YTY', 'JXS', 'HNY', 'ZYI', 'GNS', 'WNH', 'LZY', 'BUW', 'LOP', 'MJU', 'WDS', 'HTT', 'SQD', 'JNG'}
# 2017-09-26 proccesseed
# No match for airports:  {'DQA', 'LOP', 'TCZ', 'UKA', 'YKH', 'HXD'}
# 2017-09-27 proccesseed
# No match for airports:  {'DQA', 'DCY', 'JXS', 'TCZ', 'SHS', 'ECP', 'GYU', 'DSS', 'BWX'}
# 2017-09-28 proccesseed
# No match for airports:  {'DQA', 'GYS', 'LOP', 'DCY', 'RKZ', 'HNY', 'TCZ', 'BEJ', 'KVN', 'HXD', 'DSS'}
# 2017-09-29 proccesseed
# No match for airports:  {'LUW', 'WMT', 'ZUJ', 'DYN', 'SHF', 'LDS', 'LOP', 'JXA', 'WDS', 'TCZ', 'FSZ', 'UKA', 'LFQ', 'RHD', 'LLV', 'DTB', 'LPF', 'DSS'}
# 2017-09-30 proccesseed
# No match for airports:  {'GYS', 'RIZ', 'AEB', 'KVN', 'ECP', 'QSZ'}
# 2017-10-01 proccesseed
# No match for airports:  {'WMT', 'WLI', 'ZUJ', 'DYN', 'LOP', 'TVS', 'KTG', 'NLH', 'GMQ', 'WDS', 'HNY', 'ZYI', 'BAR', 'TCZ', 'KVN', 'ECP', 'FSZ', 'HXD', 'NYT', 'HDG'}
# 2017-10-02 proccesseed
# No match for airports:  {'WMT', 'DCY', 'NLH', 'BEJ', 'SHS', 'HXD', 'LLV', 'DQA', 'LDS', 'GMQ', 'ECP', 'HDG', 'DYN', 'RIZ', 'JXS', 'HNY', 'BAR', 'GNS', 'WNH', 'ZUJ', 'LOP', 'WUT', 'PSU', 'WDS', 'HTT', 'SQD', 'JNG', 'FLZ'}
# 2017-10-03 proccesseed
# No match for airports:  {'DCY', 'WUT', 'GMQ', 'WDS', 'GNS', 'HDG'}
# 2017-10-04 proccesseed
# No match for airports:  {'HMI', 'GYS', 'DYN', 'WDS', 'HNY', 'ZYI', 'BAR', 'KVN', 'ECP', 'FSZ', 'YKH', 'JIQ', 'UKA'}
# 2017-10-05 proccesseed
# No match for airports:  {'ECP', 'LOP', 'WNH', 'LLO'}
# 2017-10-06 proccesseed
# No match for airports:  {'KVN', 'LLV', 'DSS', 'DQA', 'LDS', 'HPG', 'YKH', 'LFQ', 'JXA', 'DYN', 'SQG', 'JXS', 'JIQ', 'WNH', 'BWX', 'KOS', 'ZUJ', 'LOP', 'PSU', 'JNG', 'FLZ', 'PKN'}
# 2017-10-07 proccesseed
# No match for airports:  {'DQA', 'DYN', 'LOP', 'GNS', 'ECP'}
# 2017-10-08 proccesseed
# No match for airports:  {'DCY', 'NDS', 'JSJ', 'BEJ', 'KVN', 'TVX', 'DSS', 'DQA', 'WLI', 'RKZ', 'GMQ', 'AEB', 'TCZ', 'ECP', 'JXA', 'QSZ', 'HDG', 'DYN', 'ZYI', 'GNS', 'JIQ', 'BWX', 'ZUJ', 'LOP', 'PSU', 'HTT', 'UKA', 'JNG', 'NYT', 'DTB'}
# 2017-10-09 proccesseed
# No match for airports:  {'KVN', 'RCU', 'TVX', 'DSS', 'HMI', 'LDS', 'PRA', 'GMQ', 'TCZ', 'JIC', 'DYN', 'JXS', 'ZYI', 'BAR', 'JIQ', 'BWX', 'BUW', 'ZUJ', 'LOP', 'PSU', 'WDS', 'HTT', 'FSZ', 'JNG', 'NYT'}
# 2017-10-10 proccesseed
# No match for airports:  {'KTG', 'NLH', 'KVN', 'DSS', 'DQA', 'RKZ', 'PRA', 'TCZ', 'JBB', 'YKH', 'LFQ', 'JXA', 'QSZ', 'HDG', 'DYN', 'LLO', 'HNY', 'ZYI', 'BAR', 'GNS', 'JIQ', 'BWX', 'BUW', 'ZUJ', 'WDS', 'HTT', 'JNG'}
# 2017-10-11 proccesseed
# No match for airports:  {'DQA', 'DYN', 'RIZ', 'JXS', 'TCZ', 'KVN', 'FSZ'}
# 2017-10-12 proccesseed
# No match for airports:  {'DQA', 'RKZ', 'LOP', 'GMQ', 'JXS', 'HNY', 'ZYI', 'HTT', 'TCZ', 'KVN', 'RCU', 'YKH', 'UKA', 'JXA', 'DSS', 'BWX'}
# 2017-10-13 proccesseed
# No match for airports:  {'DQA', 'WMT', 'ZUJ', 'DYN', 'LOP', 'JXS', 'HNY', 'WDS', 'TCZ', 'KVN', 'ECP', 'FSZ', 'UKA', 'WNH', 'LLV', 'LPF', 'DSS'}
# 2017-10-14 proccesseed
# No match for airports:  {'DQA', 'WLI', 'ZUJ', 'DYN', 'HMI', 'RIZ', 'HPG', 'LLO', 'NLH', 'JXS', 'BEJ', 'TCZ', 'SHS', 'KVN', 'ECP', 'YKH', 'JMJ', 'WNH'}
# 2017-10-15 proccesseed
# No match for airports:  {'WDS', 'JXS', 'ZYI', 'SXK', 'HNY', 'FSZ', 'WNH', 'LZY', 'BWX', 'DSS'}
# 2017-10-16 proccesseed
# No match for airports:  {'HMI', 'ZUJ', 'DYN', 'LDS', 'LOP', 'PRA', 'WDS', 'HNY', 'ZYI', 'BAR', 'BEJ', 'HTT', 'KVN', 'SHS', 'YKH', 'LFQ', 'LLV'}
# 2017-10-17 proccesseed
# No match for airports:  {'JSJ', 'BEJ', 'KVN', 'DQA', 'WLI', 'HMI', 'RKZ', 'ECP', 'RIZ', 'YTY', 'JXS', 'HNY', 'ZYI', 'BAR', 'JIQ', 'WNH', 'BWX', 'GYS', 'ZUJ', 'LOP', 'SQD', 'FSZ', 'JNG', 'JMJ', 'DTB'}
# 2017-10-18 proccesseed
# No match for airports:  {'DQA', 'ZUJ', 'WDS', 'HNY', 'KVN', 'ECP', 'LZY'}
# 2017-10-19 proccesseed
# No match for airports:  {'DQA', 'HMI', 'WLI', 'DYN', 'RKZ', 'NLH', 'GMQ', 'JXS', 'HNY', 'ZYI', 'BAR', 'WDS', 'KVN', 'ECP', 'LFQ', 'JNG', 'JIC', 'FLZ'}
# 2017-10-20 proccesseed
# No match for airports:  {'KVN', 'WDS', 'HNY', 'LOP'}
# 2017-10-21 proccesseed
# No match for airports:  {'HNY', 'HTT', 'BAR', 'FYN', 'HDG'}
# 2017-10-22 proccesseed
# No match for airports:  {'LUW', 'TVS', 'LOP', 'RIZ', 'DCY', 'WDS', 'HNY', 'JSJ', 'BEJ', 'SQD', 'KVN', 'NYT', 'JMJ', 'QSZ', 'BWX'}
# 2017-10-23 proccesseed
# No match for airports:  {'DYN', 'RKZ', 'PRA', 'WDS', 'BAR', 'YSQ', 'BEJ', 'JIQ', 'LLV', 'DTB', 'DSS'}
# 2017-10-24 proccesseed
# No match for airports:  {'WMT', 'YKH', 'BAR', 'WUT'}
# 2017-10-25 proccesseed
# No match for airports:  {'LUW', 'LOP', 'RKZ', 'HNY', 'ZYI', 'TCZ', 'ECP', 'JNG', 'RHD', 'BWX'}
# 2017-10-26 proccesseed
# No match for airports:  {'WMT', 'DCY', 'KTG', 'KVN', 'DSS', 'WLI', 'DQA', 'LDS', 'TCZ', 'ECP', 'LFQ', 'DYN', 'RIZ', 'JXS', 'HNY', 'GNS', 'LZY', 'LUW', 'BUW', 'ZUJ', 'LOP', 'WDS', 'FSZ', 'FLZ', 'NYT'}
# 2017-10-27 proccesseed
# No match for airports:  {'DQA', 'BUW', 'HMI', 'JXS', 'JMJ'}
# 2017-10-28 proccesseed
# No match for airports:  {'DQA', 'WLI', 'LOP', 'DCY', 'MJU', 'WDS', 'HNY', 'CWJ', 'BEJ', 'ECP', 'TVX', 'UKA', 'LFQ', 'YKH', 'JNG'}
# 2017-10-29 proccesseed
# No match for airports:  {'JIQ', 'LOP', 'FLZ', 'WUT'}
# 2017-10-30 proccesseed
# No match for airports:  {'NDS', 'KVN', 'TVX', 'LDS', 'YSQ', 'ECP', 'YKH', 'JXA', 'CHG', 'QSZ', 'DYN', 'JXS', 'HNY', 'SXK', 'JIQ', 'BWX', 'BUW', 'LUW', 'KOS', 'LOP', 'WDS', 'CWJ'}
# 2017-10-31 proccesseed
# No match for airports:  {'LOP', 'MJU', 'YTY', 'GMQ', 'WDS', 'JXS', 'HTT', 'BAR', 'KVN', 'ECP', 'TVX', 'YKH', 'LFQ', 'CHG', 'FYN', 'QSZ'}
# 2017-11-01 proccesseed
# No match for airports:  {'DYN', 'LOP', 'DCY', 'GYU', 'HPG', 'WDS', 'TCZ', 'JBB', 'JUH'}
# 2017-11-02 proccesseed
# No match for airports:  {'WMT', 'DQA', 'DYN', 'LOP', 'RIZ', 'LLO', 'WDS', 'HNY', 'ZYI', 'FSZ', 'YKH', 'TVX', 'JNG', 'JIC', 'NYT', 'LPF'}
# 2017-11-03 proccesseed
# No match for airports:  {'LUW', 'ZUJ', 'JXS', 'NDS', 'ZYI', 'HNY', 'TCZ', 'BEJ', 'JBB', 'SHS', 'ECP', 'UKA', 'JNG', 'FLZ', 'GYU', 'LLV', 'DTB'}
# 2017-11-04 proccesseed
# No match for airports:  {'DQA', 'LUW', 'ZUJ', 'LOP', 'RIZ', 'HPG', 'PRA', 'JXS', 'TCZ', 'FSZ', 'NYT', 'LPF', 'DSS'}
# 2017-11-05 proccesseed
# No match for airports:  {'ZUJ', 'GYU', 'SQG', 'LOP', 'KTG', 'WUT', 'KOS', 'AEB', 'WDS', 'JXS', 'KVN', 'JXA', 'JUH', 'NYT', 'PKN', 'DSS'}
# 2017-11-06 proccesseed
# No match for airports:  {'WMT', 'BEJ', 'KVN', 'DSS', 'HMI', 'WLI', 'TCZ', 'JBB', 'DYN', 'YTY', 'HNY', 'ZYI', 'BAR', 'GNS', 'JIQ', 'RAQ', 'BWX', 'LOP', 'WUT', 'CWJ', 'JMJ', 'NYT'}
# 2017-11-07 proccesseed
# No match for airports:  {'RKZ', 'YTY', 'JXS', 'SQD', 'KVN', 'ECP', 'JNG', 'JIC'}
# 2017-11-08 proccesseed
# No match for airports:  {'DQA', 'LLB', 'BUW', 'WUT', 'JXS', 'ZYI', 'LFQ', 'FLZ', 'DSS'}
# 2017-11-09 proccesseed
# No match for airports:  {'DYN', 'TVS', 'LOP', 'KTG', 'GMQ', 'WDS', 'JXS', 'SXK', 'YSQ', 'KVN', 'JNG', 'JMJ', 'DSS'}
# 2017-11-10 proccesseed
# No match for airports:  {'WMT', 'DYN', 'LOP', 'YTY', 'HPG', 'AEB', 'WDS', 'JXS', 'HTT', 'TCZ', 'KVN', 'ECP', 'TVX', 'FSZ', 'JNG', 'JMJ'}
# 2017-11-11 proccesseed
# No match for airports:  {'ZUJ', 'WDS', 'ZYI', 'CWJ', 'KVN', 'JIC', 'GYU'}
# 2017-11-12 proccesseed
# No match for airports:  {'DQA', 'LDS', 'DCY', 'HPG', 'GMQ', 'WDS', 'KVN', 'FSZ', 'JXA', 'GYU', 'NYT'}
# 2017-11-13 proccesseed
# No match for airports:  {'DQA', 'ZUJ', 'DYN', 'LOP', 'PSU', 'AEB', 'WDS', 'NDS', 'ZYI', 'GMQ', 'TCZ', 'JMJ', 'YSQ', 'UKA', 'JNG', 'JIC', 'NYT', 'WNH', 'RAQ'}
# 2017-11-14 proccesseed
# No match for airports:  {'ZUJ', 'TVS', 'AEB', 'BEJ', 'KVN', 'JMJ', 'LLV', 'DSS'}
# 2017-11-15 proccesseed
# No match for airports:  {'WNH', 'LLV', 'TCZ'}
# 2017-11-16 proccesseed
# No match for airports:  {'WLI', 'NGQ', 'ZUJ', 'DYN', 'LOP', 'SQG', 'WUT', 'HNY', 'FYN', 'HTT', 'BAR', 'JBB', 'KVN', 'GNS', 'JIC', 'GYU', 'LLV'}
# 2017-11-17 proccesseed
# No match for airports:  {'DQA', 'KOS', 'DYN', 'LOP', 'DCY', 'MJU', 'HPG', 'GMQ', 'LDS', 'BWX', 'HNY', 'ZYI', 'BAR', 'SHS', 'JIQ', 'YKH', 'WNH', 'HDG', 'LPF', 'DSS'}
# 2017-11-18 proccesseed
# No match for airports:  {'HMI', 'DQA', 'RKZ', 'LOP', 'AEB', 'WDS', 'JXS', 'BAR', 'BEJ', 'JMJ', 'KVN', 'TCZ', 'YKH', 'JNG', 'JXA', 'FYN', 'LPF', 'DSS'}
# 2017-11-19 proccesseed
# No match for airports:  {'WMT', 'KVN', 'DSS', 'DQA', 'PRA', 'GMQ', 'TCZ', 'JBB', 'RIZ', 'LLO', 'JXS', 'ZYI', 'LSW', 'JIQ', 'GYU', 'WNH', 'LZY', 'LOP', 'WUT', 'WDS', 'JNG'}
# 2017-11-20 proccesseed
# No match for airports:  {'WMT', 'BEJ', 'TVX', 'DSS', 'WLI', 'DQA', 'LDS', 'HPG', 'PRA', 'GMQ', 'AEB', 'LFQ', 'JIC', 'NGQ', 'DYN', 'RIZ', 'HNY', 'JIQ', 'LUW', 'GYS', 'ZUJ', 'KOS', 'LOP', 'BUW', 'WDS', 'SQD', 'JNG'}
# 2017-11-21 proccesseed
# No match for airports:  {'KVN', 'JUH', 'LLV', 'DSS', 'WLI', 'HMI', 'DQA', 'LDS', 'TCZ', 'ECP', 'YKH', 'JXA', 'HDG', 'DYN', 'HNY', 'BAR', 'GNS', 'GYU', 'LOP', 'WDS', 'UKA', 'JNG'}
# 2017-11-22 proccesseed
# No match for airports:  {'BUW', 'DQA', 'LOP', 'GMQ', 'JXS', 'WDS', 'JBB', 'QSZ', 'LPF', 'BWX'}
# 2017-11-23 proccesseed
# No match for airports:  {'WLI', 'GYS', 'HMI', 'DYN', 'LOP', 'DQA', 'LDS', 'PSU', 'JXA', 'CWJ', 'HTT', 'TCZ', 'KVN', 'TVX', 'FLZ', 'WNH', 'DSS'}
# 2017-11-24 proccesseed
# No match for airports:  {'KTG', 'BEJ', 'KVN', 'SHS', 'LLV', 'DSS', 'LDS', 'PRA', 'TCZ', 'YKH', 'LFQ', 'NGQ', 'DYN', 'JXS', 'ZYI', 'GYU', 'GYS', 'ZUJ', 'WUT', 'WDS', 'FLZ'}
# 2017-11-25 proccesseed
# No match for airports:  {'JIQ', 'TVX', 'JXA'}
# 2017-11-26 proccesseed
# No match for airports:  {'HMI', 'CHG', 'LDS', 'LOP', 'RKZ', 'PKN', 'WUT', 'RIZ', 'JXA', 'WDS', 'HTT', 'YSQ', 'TCZ', 'KVN', 'TVX', 'LFQ', 'JMJ', 'QSZ', 'RAQ', 'DSS'}
# 2017-11-27 proccesseed
# No match for airports:  {'NLH', 'BEJ', 'KVN', 'TVX', 'DQA', 'WLI', 'HPG', 'AEB', 'GMQ', 'YKH', 'JXA', 'HDG', 'RIZ', 'ZYI', 'JIQ', 'ZUJ', 'LOP', 'FSZ', 'JNG', 'NYT', 'PKN'}
# 2017-11-28 proccesseed
# No match for airports:  {'GYS', 'RKZ', 'HNY', 'HTT', 'KVN', 'TVX', 'JXA', 'LLV', 'HDG'}
# 2017-11-29 proccesseed
# No match for airports:  {'DYN', 'LOP', 'ECP', 'FSZ', 'CHG', 'LLV'}
# 2017-11-30 proccesseed
# No match for airports:  {'BUW', 'HMI', 'ZUJ', 'DQA', 'LOP', 'DYN', 'KTG', 'WDS', 'HNY', 'TCZ', 'KVN', 'ECP', 'JNG', 'FLZ', 'JUH', 'NYT'}
# 2017-12-01 proccesseed
# No match for airports:  {'DCY', 'JXS', 'HNY', 'ZYI', 'TCZ', 'LFQ', 'NGQ', 'DSS'}
# 2017-12-02 proccesseed
# No match for airports:  {'BEJ', 'KVN', 'LLV', 'DSS', 'DQA', 'LDS', 'RKZ', 'HPG', 'AEB', 'TCZ', 'LFQ', 'RHD', 'JXA', 'DYN', 'LLO', 'HNY', 'ZYI', 'WNH', 'BUW', 'GYS', 'LOP', 'SHF', 'WDS'}
# 2017-12-03 proccesseed
# No match for airports:  {'KTG', 'BEJ', 'KVN', 'SHS', 'HXD', 'DSS', 'HMI', 'DQA', 'LDS', 'HPG', 'TCZ', 'ECP', 'LFQ', 'JIC', 'JXA', 'HDG', 'DYN', 'RIZ', 'JXS', 'WNH', 'BWX', 'ZUJ', 'LOP', 'UKA', 'JMJ'}
# 2017-12-04 proccesseed
# No match for airports:  {'LDS', 'LOP', 'WDS', 'ZYI', 'LSW', 'LFQ', 'JMJ', 'DSS'}
# 2017-12-05 proccesseed
# No match for airports:  {'DYN', 'ZYI', 'KVN', 'GYU', 'HDG', 'DSS'}
# 2017-12-06 proccesseed
# No match for airports:  {'SHS', 'JUH', 'LLV', 'DSS', 'DQA', 'WLI', 'LDS', 'RKZ', 'AEB', 'HDG', 'DYN', 'JXS', 'HNY', 'ZYI', 'SXK', 'LSW', 'WNH', 'LOP', 'SHF', 'WDS', 'FSZ', 'UKA', 'JMJ', 'NYT'}
# 2017-12-07 proccesseed
# No match for airports:  {'DQA', 'LDS', 'SHF', 'RHD', 'RIZ', 'PRA', 'GMQ', 'LOP', 'WDS', 'HNY', 'ZYI', 'BEJ', 'JNG', 'JMJ', 'GYU', 'NYT', 'WNH', 'LLV', 'HDG'}
# 2017-12-08 proccesseed
# No match for airports:  {'DQA', 'LDS', 'TCZ', 'ECP', 'FSZ', 'LFQ', 'JNG'}
# 2017-12-09 proccesseed
# No match for airports:  {'BUW', 'DQA', 'LOP', 'RIZ', 'AEB', 'JXS', 'ZYI', 'BEJ', 'JBB', 'LFQ', 'JNG'}
# 2017-12-10 proccesseed
# No match for airports:  {'BUW', 'GYS', 'LDS', 'LOP', 'DYN', 'WUT', 'JXA', 'WDS', 'HNY', 'FYN', 'BEJ', 'SQD', 'KVN', 'JBB', 'ECP', 'FLZ', 'TCZ', 'JMJ', 'GYU', 'DSS'}
# 2017-12-11 proccesseed
# No match for airports:  {'LUW', 'GYS', 'LDS', 'PRA', 'JXA', 'WDS', 'ZYI', 'SXK', 'KVN', 'JIQ', 'TVX', 'ECP', 'FSZ', 'FLZ', 'LLV', 'HDG', 'DSS'}
# 2017-12-12 proccesseed
# No match for airports:  {'WMT', 'KVN', 'DQA', 'WLI', 'PRA', 'TCZ', 'ECP', 'LFQ', 'RIZ', 'YTY', 'JXS', 'ZYI', 'BAR', 'GNS', 'JIQ', 'GYU', 'BUW', 'ZUJ', 'PSU', 'WDS', 'UKA'}
# 2017-12-13 proccesseed
# No match for airports:  {'DQA', 'WLI', 'LDS', 'LOP', 'TVS', 'PRA', 'WDS', 'JXS', 'KVN', 'GNS', 'SHS', 'ECP', 'YKH', 'FLZ', 'QSZ', 'LLV', 'HDG', 'DSS'}
# 2017-12-14 proccesseed
# No match for airports:  {'DQA', 'PKN', 'LOP', 'RIZ', 'HPG', 'KTG', 'LDS', 'JSJ', 'SQD', 'BEJ', 'KVN', 'GNS', 'ECP', 'JBB', 'JNG', 'JXA', 'WNH', 'LLV', 'HDG'}
# 2017-12-15 proccesseed
# No match for airports:  {'KVN', 'TVX', 'LLV', 'DSS', 'RKZ', 'PRA', 'GMQ', 'ECP', 'LFQ', 'JXA', 'DYN', 'JIQ', 'WNH', 'BWX', 'LUW', 'ZUJ', 'LOP', 'SHF', 'MJU', 'WDS', 'HTT', 'FSZ', 'UKA', 'JNG', 'FLZ', 'LPF'}
# 2017-12-16 proccesseed
# No match for airports:  {'KTG', 'KVN', 'TVX', 'JUH', 'LLV', 'DSS', 'DQA', 'AEB', 'TCZ', 'ECP', 'LFQ', 'CHG', 'QSZ', 'DYN', 'RIZ', 'HNY', 'ZYI', 'BAR', 'GNS', 'JIQ', 'GYU', 'WNH', 'BUW', 'GYS', 'LOP', 'WUT', 'WDS', 'CWJ', 'JNG', 'PKN'}
# 2017-12-17 proccesseed
# No match for airports:  {'BUW', 'DQA', 'LLB', 'SQG', 'LOP', 'RIZ', 'WDS', 'ZYI', 'BEJ', 'ECP', 'TVX', 'JMJ', 'QSZ'}
# 2017-12-18 proccesseed
# No match for airports:  {'DQA', 'DYN', 'RIZ', 'JXS', 'WDS', 'HNY', 'BAR', 'KVN', 'ECP', 'TVX', 'LFQ', 'JNG', 'NYT', 'BWX', 'DSS'}
# 2017-12-19 proccesseed
# No match for airports:  {'BUW', 'GYU', 'LOP', 'DYN', 'KTG', 'YTY', 'FYN', 'TCZ', 'SQD', 'KVN', 'JMJ', 'ECP', 'HXD', 'FLZ', 'JNG', 'QSZ', 'WNH', 'LLV', 'DSS', 'BWX'}
# 2017-12-20 proccesseed
# No match for airports:  {'WMT', 'GYS', 'WLI', 'DYN', 'LOP', 'LDS', 'MJU', 'JXS', 'ZYI', 'KVN', 'JIQ', 'JNG', 'DSS'}
# 2017-12-21 proccesseed
# No match for airports:  {'WMT', 'LOP', 'SHF', 'PSU', 'WDS', 'LPF', 'KVN', 'JBB', 'GNS', 'TVX', 'ECP', 'SHS', 'FLZ', 'GYU', 'LLV', 'HDG', 'BWX', 'DSS'}
# 2017-12-22 proccesseed
# No match for airports:  {'WMT', 'ZUJ', 'DYN', 'LOP', 'SHF', 'AEB', 'WDS', 'ZYI', 'LPF', 'TCZ', 'SHS', 'TVX', 'LFQ', 'GYU', 'NYT', 'WNH', 'HDG', 'BWX', 'DSS'}
# 2017-12-23 proccesseed
# No match for airports:  {'BUW', 'DQA', 'ZUJ', 'MJU', 'WDS', 'HNY', 'CWJ', 'TCZ', 'KVN', 'ECP', 'FSZ', 'YKH', 'DSS'}
# 2017-12-24 proccesseed
# No match for airports:  {'DQA', 'GYS', 'BUW', 'DYN', 'LOP', 'SQG', 'MJU', 'RIZ', 'AEB', 'CHG', 'WDS', 'ZYI', 'TCZ', 'JNG', 'RHD'}
# 2017-12-25 proccesseed
# No match for airports:  {'DQA', 'WMT', 'KOS', 'RIZ', 'HPG', 'DCY', 'JXS', 'HNY', 'ZYI', 'TCZ', 'JBB', 'ECP', 'JIQ', 'JNG', 'GYU', 'QSZ', 'DTB', 'LPF'}
# 2017-12-26 proccesseed
# No match for airports:  {'DQA', 'ZUJ', 'LOP', 'SHF', 'YTY', 'WUT', 'TVS', 'WDS', 'BAR', 'YSQ', 'BEJ', 'KVN', 'ECP', 'FSZ', 'LFQ', 'JUH', 'DTB', 'LPF'}
# 2017-12-27 proccesseed
# No match for airports:  {'LOP', 'HPG', 'YTY', 'JXS', 'BEJ', 'YSQ', 'GNS', 'KVN', 'TCZ', 'TVX', 'JNG', 'DSS'}
# 2017-12-28 proccesseed
# No match for airports:  {'WMT', 'KTG', 'BEJ', 'KVN', 'RCU', 'TVX', 'DSS', 'DQA', 'HMI', 'AEB', 'TCZ', 'ECP', 'YKH', 'JXA', 'CHG', 'DYN', 'RIZ', 'YTY', 'JXS', 'HNY', 'ZYI', 'WNH', 'BWX', 'ZUJ', 'LOP', 'SHF', 'WUT', 'WDS', 'HTT', 'FSZ', 'JNG', 'NYT', 'PKN'}
# 2017-12-29 proccesseed
# No match for airports:  {'LOP', 'RCU', 'YKH', 'JMJ', 'WNH'}
# 2017-12-30 proccesseed
# No match for airports:  {'KTG', 'NLH', 'NDS', 'KVN', 'LLV', 'DSS', 'DQA', 'WLI', 'GMQ', 'ECP', 'YKH', 'QSZ', 'DYN', 'JXS', 'ZYI', 'BWX', 'LOP', 'MJU', 'WUT', 'PSU', 'HTT', 'FSZ', 'JNG', 'LPF'}
# 2017-12-31 proccesseed

# %%
print(airline_names)
# Out:
# set()
